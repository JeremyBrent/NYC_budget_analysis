# %%
import pandas as pd

# %%
data = pd.read_csv("Data/Capital_Budget.csv")
data
# Out:
#       Published Date Project Type         Project Type Name Budget Line  \
# 0           20180201           AG  DEPARTMENT FOR THE AGING     AG 0001
# 1           20180201           AG  DEPARTMENT FOR THE AGING     AG 0002
# 2           20180201           AG  DEPARTMENT FOR THE AGING    AG MN235
# 3           20180201           BR          WATERWAY BRIDGES     BR 0231
# 4           20180201           BR          WATERWAY BRIDGES     BR 0253
# ...              ...          ...                       ...         ...
# 5798        20200713           WP   WATER POLLUTION CONTROL     WP 0247
# 5799        20200713           WP   WATER POLLUTION CONTROL     WP 0269
# 5800        20200713           WP   WATER POLLUTION CONTROL     WP 0282
# 5801        20200713           WP   WATER POLLUTION CONTROL     WP 0285
# 5802        20200713           WP   WATER POLLUTION CONTROL     WP D169
#
#                                       Budget Line Title Funding Type  \
# ...

# %%
by_year = data["First Fiscal Year"].value_counts()
total = len(data)
by_year / total *100
# Out:
# 2020    33.861796
# 2019    33.172497
# 2021    32.965707
# Name: First Fiscal Year, dtype: float64
